# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
gov_data = pd.read_csv('gov.csv', index_col='SALEDATE', parse_dates=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
gov_data
# Out:
#                        PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# SALEDATE
# 2012-09-27  1075F00108000000            4720.0
# 2015-01-06  0011A00237000000               0.0
# 2012-10-26  0011J00047000000            1903.0
# 2017-03-06  0113B00029000000             479.0
# 2015-02-04  0119S00024000000            5418.0
# ...                      ...               ...              ...
# 2019-05-30  0424D00020000000               0.0
# 2019-05-10  0115B00050000000             466.0
# 2019-05-22  0028P00027000000             300.0
# 2019-05-15  0613B00301000000            1230.0
# 2019-04-04  0383B00358000000             901.0
#
#            PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# SALEDATE
# 2012-09-27                NaN             HIGHPOINT                 DR
# 2015-01-06                NaN               LOMBARD                 ST
# 2012-10-26                NaN                FORBES                AVE
# ...

# %%
gov_data.shape
# Out:
# (307756, 23)

# %%
gov_data.head()
# Out:
#                        PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# SALEDATE
# 2012-09-27  1075F00108000000            4720.0
# 2015-01-06  0011A00237000000               0.0
# 2012-10-26  0011J00047000000            1903.0
# 2017-03-06  0113B00029000000             479.0
# 2015-02-04  0119S00024000000            5418.0
#
#            PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# SALEDATE
# 2012-09-27                NaN             HIGHPOINT                 DR
# 2015-01-06                NaN               LOMBARD                 ST
# 2012-10-26                NaN                FORBES                AVE
# 2017-03-06                NaN             ROOSEVELT                AVE
# 2015-02-04                NaN              CARNEGIE                 ST
#
#            PROPERTYADDRESSUNITDESC PROPERTYUNITNO PROPERTYCITY PROPERTYSTATE  \
# SALEDATE
# 2012-09-27                     NaN            NaN     GIBSONIA            PA
# ...

# %%
gov_data.describe()
# Out:
#        PROPERTYHOUSENUM    PROPERTYZIP     SCHOOLCODE       MUNICODE  \
# count     307738.000000  307755.000000  307756.000000  307756.000000
# mean        1440.010444   15169.627437      28.999058     688.607075
# std         2063.976108      92.813989      15.068535     340.616427
# min            0.000000   15003.000000       1.000000     101.000000
# 25%          159.000000   15108.000000      17.000000     202.000000
# 50%          603.000000   15204.000000      29.000000     874.000000
# 75%         1813.000000   15221.000000      46.000000     927.000000
# max        39389.000000   16229.000000      50.000000     953.000000
#
#               PRICE
# count  3.052780e+05
# mean   1.725544e+05
# std    9.737428e+05
# min    0.000000e+00
# 25%    5.000000e+02
# 50%    7.600000e+04
# 75%    1.850000e+05
# max    1.487529e+08

# %%
gov = gov_data.dropna(axis=0)

# %%
gov
# Out:
#                        PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# SALEDATE
# 2016-09-22  0084P00171000200             384.0
# 2012-01-03  0084K00298020300             333.0
# 2012-01-03  0052E00033005400             552.0
# 2012-01-06  0052E00011030200             128.0
# 2012-02-13  0085A00168000600             724.0
# ...                      ...               ...              ...
# 2019-12-10  0160J00060030100             227.0
# 2020-08-29  0084K00314010300             363.0
# 2020-10-06  0027H00144008300             166.0
# 2019-12-31  0027H00117070400             220.0
# 2019-05-07  0052A00183020500             425.0
#
#            PROPERTYADDRESSDIR PROPERTYADDRESSSTREET PROPERTYADDRESSSUF  \
# SALEDATE
# 2016-09-22                  S              HIGHLAND                AVE
# 2012-01-03                  S              HIGHLAND                AVE
# 2012-01-03                  N               NEVILLE                 ST
# ...

# %%
gov.shape
# Out:
# (859, 23)

# %%
gov.describe()
# Out:
#        PROPERTYHOUSENUM   PROPERTYZIP  SCHOOLCODE    MUNICODE         PRICE
# count        859.000000    859.000000  859.000000  859.000000  8.590000e+02
# mean         266.804424  15211.225844   44.640279  190.708964  1.762075e+05
# std          147.966713      5.641400    6.596765  229.959197  2.582858e+05
# min            0.000000  15202.000000    9.000000  104.000000  0.000000e+00
# 25%          144.000000  15206.000000   47.000000  104.000000  6.875000e+04
# 50%          220.000000  15213.000000   47.000000  104.000000  1.380000e+05
# 75%          363.000000  15213.000000   47.000000  107.000000  2.250000e+05
# max          943.000000  15233.000000   47.000000  926.000000  5.872734e+06

# %%
gov['PRICE'].value_counts().plot()

# %%
gov['PRICE'].hist()

# %%
gov['PRICE'].agg(['max', 'min', 'mean', 'std'])
# Out:
# max     5.872734e+06
# min     0.000000e+00
# mean    1.762075e+05
# std     2.582858e+05
# Name: PRICE, dtype: float64

# %%
gov.groupby(['PRICE']).mean()
# Out:
#            PROPERTYHOUSENUM   PROPERTYZIP  SCHOOLCODE    MUNICODE
# PRICE
# 0.0              283.066667  15210.400000   45.800000  151.333333
# 1.0              278.429752  15211.462810   44.256198  205.322314
# 10.0             291.142857  15211.714286   44.428571  206.571429
# 572.0            227.000000  15202.000000   29.000000  802.000000
# 1800.0            16.000000  15216.000000   26.000000  926.000000
# ...                     ...           ...         ...         ...
# 980000.0         220.000000  15213.000000   47.000000  104.000000
# 1200000.0        146.000000  15213.000000   47.000000  104.000000
# 1300000.0        537.000000  15213.000000   47.000000  107.000000
# 1933000.0        128.000000  15213.000000   47.000000  104.000000
# 5872734.0        455.000000  15203.000000   47.000000  116.000000
#
# [393 rows x 4 columns]

# %%
sns.heatmap(gov.corr())

# %%
gov['2016':'2019']['PRICE'].plot()

# %%
gov.loc['2012':'2016', 'PRICE'].resample('M').mean().plot()

# %%
gov.loc['2012':'2016', 'PRICE'].resample('M').std().plot()

# %%
gov.loc['2012':'2016', 'PRICE'].resample('M').agg(['max', 'min', 'mean', 'std'])
# Out:
#                   max       min           mean            std
# SALEDATE
# 2012-01-31    95000.0       1.0   61667.000000   53462.806389
# 2012-02-29   380000.0       1.0  134200.200000  146352.768680
# 2012-03-31   210000.0       1.0   88475.250000   87845.566291
# 2012-04-30   790075.0   65000.0  203010.714286  260190.973076
# 2012-05-31   249000.0       1.0  116244.555556   81081.078044
# 2012-06-30   349500.0       1.0  177150.200000  137877.523278
# 2012-07-31   320000.0       1.0  106008.800000  100361.859610
# 2012-08-31   220000.0       0.0   61944.777778   79379.508185
# 2012-09-30   395000.0       1.0  121515.300000  136560.341226
# 2012-10-31   228000.0   40000.0  120200.000000   87733.687943
# 2012-11-30   167500.0       1.0   55417.166667   75835.184228
# 2012-12-31   825000.0       1.0  331786.000000  382121.403359
# 2013-01-31    49900.0       1.0   24950.500000   35283.921274
# 2013-02-28   102000.0    1800.0   52933.333333   50131.959201
# ...
